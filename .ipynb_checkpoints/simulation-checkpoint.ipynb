# %% [markdown]
# # **SIMULATION**

# %% [markdown]
# ### 1. Problem Setup
#
# In this notebook, we will discuss the mathematical setup of the problem in a fair amount of mathematical detail and use the `FEniCS` library to solve it. We consider the flow of incompressible fluid around a cylinder in 2D which can be described by the Navier-Stokes equations. The cylinder and the fluid are contained in the space $\Omega$ which is rectanglular and has the dimensions $L_x \times L_y$. To describe the boundaries of the space, we define $\Gamma_{cylinder}$ as the boundary of the cylinder and $\Gamma_{box} = \Gamma_{wall} \cup \Gamma_{in} \cup \Gamma_{out}$ as the boundary of the rectangle. Visually, we describe:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. FEniCS Simulation

# %% [markdown]
# We solve our equations, we use the `FEniCS` library which solves partial differential equations (PDEs) with the finite element method (FEM). FEM requires us discretise our space $\Omega$ by constructing a computational mesh. Our problem is a benchmark example and is covered in detail in the documentation at: https://fenics-course-fluids.readthedocs.io/en/latest/NavierStokes2D/NavierStokes2D.html. We will follow this tutorial closely. The first step is to import all required modules,

# %%
# Dependencies,
import dolfinx as df
from time import time

# %% [markdown]
# docker run -it --name dolfinx-container -v 'C:/Users/Prithvi/Documents/Machine-Learning/pinn-cylinder-flow:/home/dolfinx/shared' dolfinx/dolfinx:stable
#
# jupyter notebook --ip=0.0.0.0 --port=8888 --no-browser --allow-root
